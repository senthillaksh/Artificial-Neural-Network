# %%
# Importing essential libraries
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
# Loading the dataset
df = pd.read_csv('/content/drive/MyDrive/Artificial Neural Network /Churn_Modelling.csv')

# %% [markdown]
# **Exploring the dataset**

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
# Importing essential libraries for visualizations
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Visualizing the count of 'exited customers' in the dataset

sns.countplot(x='Exited', data=df)
plt.xlabel('0: Customers still with the bank, 1: Customers exited the bank')
plt.ylabel('Count')
plt.title('Bank Customers Churn Visualization')
plt.show()

# %%
df.isna().any()
# Out:
# RowNumber          False
# CustomerId         False
# Surname            False
# CreditScore        False
# Geography          False
# Gender             False
# Age                False
# Tenure             False
# Balance            False
# NumOfProducts      False
# HasCrCard          False
# IsActiveMember     False
# EstimatedSalary    False
# Exited             False
# dtype: bool

# %%
df.drop(['RowNumber','CustomerId','Surname'], axis=1, inplace=True)
df.columns
# Out:
# Index(['CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
#        'Exited'],
#       dtype='object')

# %% [markdown]
# **Feature Engineering**

# %%
# Converting 'Geography' and 'Gender' column
df = pd.get_dummies(df, drop_first=True)

# %%
df.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# 0               1        101348.88       1                  0
# 1               1        112542.58       0                  0
# 2               0        113931.57       1                  0
# 3               0         93826.63       0                  0
# 4               1         79084.10       0                  0
#
#    Geography_Spain  Gender_Male
# 0                0            0
# 1                1            0
# 2                0            0
# 3                0            0
# 4                1            0

# %%
X = df.drop('Exited', axis=1)
y = df['Exited']

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)
print('X_train size: {}, X_test size: {}'.format(X_train.shape, X_test.shape))
# Out:
# X_train size: (8000, 11), X_test size: (2000, 11)

# %% [markdown]
# **Feature Scaling**

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# **Building Artificial Neural Network (ANN)**

# %%
# Now let's make the ANN!

# Importing the Keras libraries and packages
import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout

# %%
# Initialising the ANN
classifier = Sequential()

# Adding the input layer and the first hidden layer
classifier.add(Dense(units = 10,kernel_initializer='he_uniform',activation='relu',input_dim = 11))

# Adding the second hidden layer
classifier.add(Dense(units = 10, kernel_initializer = 'he_uniform',activation='relu'))
# Adding the output layer
classifier.add(Dense(units = 1, kernel_initializer = 'glorot_uniform', activation = 'sigmoid'))

# Compiling the ANN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
classifier.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                120
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 241
# Trainable params: 241
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fitting the ANN to the Training set
model_history=classifier.fit(X_train, y_train,validation_split=0.33, batch_size = 10,epochs = 100)
# Out:
# Epoch 1/100
# 536/536 [==============================] - 6s 4ms/step - loss: 0.5375 - accuracy: 0.7449 - val_loss: 0.4606 - val_accuracy: 0.8005
# Epoch 2/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.4414 - accuracy: 0.8115 - val_loss: 0.4397 - val_accuracy: 0.8046
# Epoch 3/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.4242 - accuracy: 0.8203 - val_loss: 0.4307 - val_accuracy: 0.8076
# Epoch 4/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.4113 - accuracy: 0.8272 - val_loss: 0.4210 - val_accuracy: 0.8095
# Epoch 5/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3996 - accuracy: 0.8322 - val_loss: 0.4099 - val_accuracy: 0.8236
# Epoch 6/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3875 - accuracy: 0.8433 - val_loss: 0.4001 - val_accuracy: 0.8270
# Epoch 7/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3762 - accuracy: 0.8444 - val_loss: 0.3890 - val_accuracy: 0.8345
# Epoch 8/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3655 - accuracy: 0.8522 - val_loss: 0.3821 - val_accuracy: 0.8387
# Epoch 9/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3572 - accuracy: 0.8537 - val_loss: 0.3768 - val_accuracy: 0.8398
# Epoch 10/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3508 - accuracy: 0.8584 - val_loss: 0.3721 - val_accuracy: 0.8421
# Epoch 11/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3464 - accuracy: 0.8597 - val_loss: 0.3686 - val_accuracy: 0.8489
# Epoch 12/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3432 - accuracy: 0.8574 - val_loss: 0.3669 - val_accuracy: 0.8463
# Epoch 13/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3409 - accuracy: 0.8582 - val_loss: 0.3658 - val_accuracy: 0.8512
# Epoch 14/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3400 - accuracy: 0.8600 - val_loss: 0.3650 - val_accuracy: 0.8489
# Epoch 15/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3381 - accuracy: 0.8587 - val_loss: 0.3634 - val_accuracy: 0.8466
# Epoch 16/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3365 - accuracy: 0.8610 - val_loss: 0.3628 - val_accuracy: 0.8485
# Epoch 17/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3354 - accuracy: 0.8610 - val_loss: 0.3660 - val_accuracy: 0.8421
# Epoch 18/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3354 - accuracy: 0.8614 - val_loss: 0.3596 - val_accuracy: 0.8531
# Epoch 19/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3334 - accuracy: 0.8614 - val_loss: 0.3613 - val_accuracy: 0.8519
# Epoch 20/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3335 - accuracy: 0.8608 - val_loss: 0.3585 - val_accuracy: 0.8550
# Epoch 21/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3322 - accuracy: 0.8612 - val_loss: 0.3626 - val_accuracy: 0.8523
# Epoch 22/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3322 - accuracy: 0.8612 - val_loss: 0.3591 - val_accuracy: 0.8504
# Epoch 23/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3315 - accuracy: 0.8608 - val_loss: 0.3581 - val_accuracy: 0.8546
# Epoch 24/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3304 - accuracy: 0.8625 - val_loss: 0.3580 - val_accuracy: 0.8523
# Epoch 25/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3299 - accuracy: 0.8643 - val_loss: 0.3584 - val_accuracy: 0.8546
# Epoch 26/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3295 - accuracy: 0.8636 - val_loss: 0.3573 - val_accuracy: 0.8542
# Epoch 27/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3285 - accuracy: 0.8634 - val_loss: 0.3586 - val_accuracy: 0.8542
# Epoch 28/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3287 - accuracy: 0.8623 - val_loss: 0.3571 - val_accuracy: 0.8569
# Epoch 29/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3276 - accuracy: 0.8634 - val_loss: 0.3581 - val_accuracy: 0.8557
# Epoch 30/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3275 - accuracy: 0.8636 - val_loss: 0.3560 - val_accuracy: 0.8565
# Epoch 31/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3277 - accuracy: 0.8625 - val_loss: 0.3556 - val_accuracy: 0.8580
# Epoch 32/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3271 - accuracy: 0.8634 - val_loss: 0.3568 - val_accuracy: 0.8569
# Epoch 33/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3264 - accuracy: 0.8656 - val_loss: 0.3567 - val_accuracy: 0.8557
# Epoch 34/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3259 - accuracy: 0.8658 - val_loss: 0.3581 - val_accuracy: 0.8599
# Epoch 35/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3260 - accuracy: 0.8643 - val_loss: 0.3560 - val_accuracy: 0.8603
# Epoch 36/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3255 - accuracy: 0.8664 - val_loss: 0.3564 - val_accuracy: 0.8595
# Epoch 37/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3252 - accuracy: 0.8653 - val_loss: 0.3567 - val_accuracy: 0.8569
# Epoch 38/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3251 - accuracy: 0.8656 - val_loss: 0.3537 - val_accuracy: 0.8595
# Epoch 39/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3249 - accuracy: 0.8642 - val_loss: 0.3551 - val_accuracy: 0.8610
# Epoch 40/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3244 - accuracy: 0.8656 - val_loss: 0.3547 - val_accuracy: 0.8626
# Epoch 41/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3245 - accuracy: 0.8651 - val_loss: 0.3544 - val_accuracy: 0.8614
# Epoch 42/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3239 - accuracy: 0.8655 - val_loss: 0.3556 - val_accuracy: 0.8614
# Epoch 43/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3239 - accuracy: 0.8658 - val_loss: 0.3560 - val_accuracy: 0.8584
# Epoch 44/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3231 - accuracy: 0.8656 - val_loss: 0.3546 - val_accuracy: 0.8580
# Epoch 45/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3238 - accuracy: 0.8636 - val_loss: 0.3558 - val_accuracy: 0.8580
# Epoch 46/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3230 - accuracy: 0.8658 - val_loss: 0.3548 - val_accuracy: 0.8580
# Epoch 47/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3226 - accuracy: 0.8670 - val_loss: 0.3528 - val_accuracy: 0.8626
# Epoch 48/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3221 - accuracy: 0.8681 - val_loss: 0.3542 - val_accuracy: 0.8569
# Epoch 49/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3224 - accuracy: 0.8670 - val_loss: 0.3542 - val_accuracy: 0.8618
# Epoch 50/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3216 - accuracy: 0.8662 - val_loss: 0.3550 - val_accuracy: 0.8610
# Epoch 51/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3227 - accuracy: 0.8649 - val_loss: 0.3533 - val_accuracy: 0.8614
# Epoch 52/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3220 - accuracy: 0.8656 - val_loss: 0.3526 - val_accuracy: 0.8614
# Epoch 53/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3219 - accuracy: 0.8638 - val_loss: 0.3529 - val_accuracy: 0.8595
# Epoch 54/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3211 - accuracy: 0.8655 - val_loss: 0.3538 - val_accuracy: 0.8591
# Epoch 55/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3212 - accuracy: 0.8673 - val_loss: 0.3534 - val_accuracy: 0.8580
# Epoch 56/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3201 - accuracy: 0.8662 - val_loss: 0.3545 - val_accuracy: 0.8599
# Epoch 57/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3205 - accuracy: 0.8653 - val_loss: 0.3527 - val_accuracy: 0.8595
# Epoch 58/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3198 - accuracy: 0.8696 - val_loss: 0.3515 - val_accuracy: 0.8599
# Epoch 59/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3195 - accuracy: 0.8670 - val_loss: 0.3545 - val_accuracy: 0.8573
# Epoch 60/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3195 - accuracy: 0.8671 - val_loss: 0.3518 - val_accuracy: 0.8610
# Epoch 61/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3194 - accuracy: 0.8684 - val_loss: 0.3541 - val_accuracy: 0.8603
# Epoch 62/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3183 - accuracy: 0.8675 - val_loss: 0.3579 - val_accuracy: 0.8561
# Epoch 63/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3191 - accuracy: 0.8679 - val_loss: 0.3554 - val_accuracy: 0.8607
# Epoch 64/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3187 - accuracy: 0.8688 - val_loss: 0.3543 - val_accuracy: 0.8561
# Epoch 65/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3185 - accuracy: 0.8683 - val_loss: 0.3545 - val_accuracy: 0.8550
# Epoch 66/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3172 - accuracy: 0.8683 - val_loss: 0.3546 - val_accuracy: 0.8546
# Epoch 67/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3176 - accuracy: 0.8692 - val_loss: 0.3537 - val_accuracy: 0.8580
# Epoch 68/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3176 - accuracy: 0.8681 - val_loss: 0.3542 - val_accuracy: 0.8573
# Epoch 69/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3175 - accuracy: 0.8696 - val_loss: 0.3541 - val_accuracy: 0.8588
# Epoch 70/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3171 - accuracy: 0.8696 - val_loss: 0.3526 - val_accuracy: 0.8599
# Epoch 71/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3176 - accuracy: 0.8696 - val_loss: 0.3548 - val_accuracy: 0.8603
# Epoch 72/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3171 - accuracy: 0.8703 - val_loss: 0.3539 - val_accuracy: 0.8584
# Epoch 73/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3157 - accuracy: 0.8724 - val_loss: 0.3547 - val_accuracy: 0.8561
# Epoch 74/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3164 - accuracy: 0.8684 - val_loss: 0.3539 - val_accuracy: 0.8569
# Epoch 75/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3171 - accuracy: 0.8692 - val_loss: 0.3532 - val_accuracy: 0.8588
# Epoch 76/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3164 - accuracy: 0.8709 - val_loss: 0.3574 - val_accuracy: 0.8569
# Epoch 77/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3163 - accuracy: 0.8727 - val_loss: 0.3538 - val_accuracy: 0.8576
# Epoch 78/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3162 - accuracy: 0.8696 - val_loss: 0.3554 - val_accuracy: 0.8599
# Epoch 79/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3164 - accuracy: 0.8703 - val_loss: 0.3542 - val_accuracy: 0.8595
# Epoch 80/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3165 - accuracy: 0.8735 - val_loss: 0.3549 - val_accuracy: 0.8565
# Epoch 81/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3161 - accuracy: 0.8712 - val_loss: 0.3546 - val_accuracy: 0.8580
# Epoch 82/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3164 - accuracy: 0.8694 - val_loss: 0.3548 - val_accuracy: 0.8580
# Epoch 83/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3154 - accuracy: 0.8737 - val_loss: 0.3559 - val_accuracy: 0.8557
# Epoch 84/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3154 - accuracy: 0.8726 - val_loss: 0.3547 - val_accuracy: 0.8607
# Epoch 85/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3152 - accuracy: 0.8705 - val_loss: 0.3564 - val_accuracy: 0.8599
# Epoch 86/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3153 - accuracy: 0.8688 - val_loss: 0.3547 - val_accuracy: 0.8599
# Epoch 87/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3147 - accuracy: 0.8720 - val_loss: 0.3546 - val_accuracy: 0.8576
# Epoch 88/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3150 - accuracy: 0.8716 - val_loss: 0.3548 - val_accuracy: 0.8573
# Epoch 89/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3155 - accuracy: 0.8709 - val_loss: 0.3540 - val_accuracy: 0.8599
# Epoch 90/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3150 - accuracy: 0.8698 - val_loss: 0.3563 - val_accuracy: 0.8576
# Epoch 91/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3150 - accuracy: 0.8722 - val_loss: 0.3547 - val_accuracy: 0.8573
# Epoch 92/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3150 - accuracy: 0.8692 - val_loss: 0.3566 - val_accuracy: 0.8565
# Epoch 93/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3150 - accuracy: 0.8722 - val_loss: 0.3557 - val_accuracy: 0.8584
# Epoch 94/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3151 - accuracy: 0.8739 - val_loss: 0.3535 - val_accuracy: 0.8573
# Epoch 95/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3150 - accuracy: 0.8711 - val_loss: 0.3555 - val_accuracy: 0.8580
# Epoch 96/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3148 - accuracy: 0.8699 - val_loss: 0.3573 - val_accuracy: 0.8550
# Epoch 97/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3149 - accuracy: 0.8705 - val_loss: 0.3539 - val_accuracy: 0.8573
# Epoch 98/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3144 - accuracy: 0.8711 - val_loss: 0.3572 - val_accuracy: 0.8565
# Epoch 99/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3143 - accuracy: 0.8692 - val_loss: 0.3559 - val_accuracy: 0.8565
# Epoch 100/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3142 - accuracy: 0.8724 - val_loss: 0.3530 - val_accuracy: 0.8580

# %%
model_history.history.keys()

# %%
# summarize history for accuracy
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')
plt.show()

# %%
# summarize history for loss
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %% [markdown]
# **Model Evaluation**

# %%
# Predicting the Test set results
y_pred = classifier.predict(X_test)

# %%
y_pred

# %%
y_pred = (y_pred > 0.5)
y_pred

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm

# %%
# Plotting confusion matrix
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, xticklabels=['Did not Exit', 'Exit'], yticklabels=['Did not Exit', 'Exit'])
plt.xlabel('Predicted values')
plt.ylabel('Actual values')
plt.title('Confusion Matrix for ANN model')
plt.show()

# %%
# Calculate the Accuracy
from sklearn.metrics import accuracy_score
score = accuracy_score(y_pred,y_test)
print('The accuracy for ANN model is: {}%'.format(score*100))
# Out:
# The accuracy for ANN model is: 85.75%

# %% [markdown]
# **Predictions**

# %%
def predict_exit(sample_value):
  
  # Convert list to numpy array
  sample_value = np.array(sample_value)

  # Reshape because sample_value contains only 1 record
  sample_value = sample_value.reshape(1, -1)

  # Feature Scaling
  sample_value = sc.transform(sample_value)

  return classifier.predict(sample_value)

# %%
# Predictions
# Value order 'CreditScore','Age','Tenure','Balance','NumOfProducts','HasCrCard','IsActiveMember','EstimatedSalary','Germany','Spain','Male'.
sample_value = [738, 62, 10, 83008.31, 1, 1, 1, 42766.03, 1, 0, 1]
if predict_exit(sample_value)>0.5:
  print('Prediction: High chances of exit!')
else:
  print('Prediction: Low chances of exit.')
# Out:
# Prediction: Low chances of exit.

# %%
# Predictions
# Value order 'CreditScore','Age','Tenure','Balance','NumOfProducts','HasCrCard','IsActiveMember','EstimatedSalary','Germany','Spain','Male'.
sample_value = [805, 45, 9, 116585.97, 1, 1, 0, 189428.75, 1, 0, 0]
if predict_exit(sample_value)>0.5:
  print('Prediction: High chances of exit!')
else:
  print('Prediction: Low chances of exit.')
# Out:
# Prediction: High chances of exit!
